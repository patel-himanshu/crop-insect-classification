# %%
import os
import sys
import tensorflow.keras as keras
import tensorflow as tf
from tensorflow.python.keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D, AveragePooling2D, Dropout
from tensorflow.python.keras.models import Model
from tensorflow.python.keras.layers.merge import concatenate
from tensorflow.python.keras.regularizers import l2

# %%
def inception_model(input, filters_1x1, filters_3x3_reduce, filters_3x3, 
                    filters_5x5_reduce, filters_5x5, filters_pool_proj):

    conv_1x1 = Conv2D(filters=filters_1x1, kernel_size=(1, 1), padding='same', 
                      activation='relu', kernel_regularizer=l2(0.01))(input)
    
    conv_3x3_reduce = Conv2D(filters=filters_3x3_reduce, kernel_size=(1, 1), padding='same', 
                             activation='relu', kernel_regularizer=l2(0.01))(input)
    
    conv_3x3 = Conv2D(filters=filters_3x3, kernel_size=(3, 3), padding='same', 
                      activation='relu', kernel_regularizer=l2(0.01))(conv_3x3_reduce)
    
    conv_5x5_reduce  = Conv2D(filters=filters_5x5_reduce, kernel_size=(1, 1), padding='same', 
                              activation='relu', kernel_regularizer=l2(0.01))(input)
    
    conv_5x5 = Conv2D(filters=filters_5x5, kernel_size=(5, 5), padding='same', 
                      activation='relu', kernel_regularizer=l2(0.01))(conv_5x5_reduce)
    
    maxpool = MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same')(input)
    
    maxpool_proj = Conv2D(filters=filters_pool_proj, kernel_size=(1, 1), strides=(1, 1), padding='same', 
                          activation='relu', kernel_regularizer=l2(0.01))(maxpool)
    
    inception_output = concatenate([conv_1x1, conv_3x3, conv_5x5, maxpool_proj], axis=3)  # use tf as backend

    return inception_output

# %%
def define_model(weight_path = None):
    input = Input(shape=(32, 32, 3))

    conv1_7x7_s2 = Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2), padding='same', 
                          activation='relu', kernel_regularizer=l2(0.01))(input)

    maxpool1_3x3_s2 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(conv1_7x7_s2)

    conv2_3x3_reduce = Conv2D(filters=64, kernel_size=(1, 1), padding='same', 
                              activation='relu', kernel_regularizer=l2(0.01))(maxpool1_3x3_s2)

    conv2_3x3 = Conv2D(filters=192, kernel_size=(3, 3), padding='same', 
                       activation='relu', kernel_regularizer=l2(0.01))(conv2_3x3_reduce)

    maxpool2_3x3_s2 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(conv2_3x3)

    inception_3a = inception_model(input=maxpool2_3x3_s2, filters_1x1=64, 
                                   filters_3x3_reduce=96, filters_3x3=128, 
                                   filters_5x5_reduce=16, filters_5x5=32, filters_pool_proj=32)

    inception_3b = inception_model(input=inception_3a, filters_1x1=128, 
                                   filters_3x3_reduce=128, filters_3x3=192,
                                   filters_5x5_reduce=32, filters_5x5=96, filters_pool_proj=64)

    maxpool3_3x3_s2 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(inception_3b)

    inception_4a = inception_model(input=maxpool3_3x3_s2, filters_1x1=192, 
                                   filters_3x3_reduce=96, filters_3x3=208, 
                                   filters_5x5_reduce=16, filters_5x5=48, filters_pool_proj=64)

    inception_4b = inception_model(input=inception_4a, filters_1x1=160,
                                   filters_3x3_reduce=112, filters_3x3=224,
                                   filters_5x5_reduce=24, filters_5x5=64, filters_pool_proj=64)

    inception_4c = inception_model(input=inception_4b, filters_1x1=128, 
                                   filters_3x3_reduce=128, filters_3x3=256,
                                   filters_5x5_reduce=24, filters_5x5=64, filters_pool_proj=64)

    inception_4d = inception_model(input=inception_4c, filters_1x1=112,
                                   filters_3x3_reduce=144, filters_3x3=288, 
                                   filters_5x5_reduce=32, filters_5x5=64, filters_pool_proj=64)

    inception_4e = inception_model(input=inception_4d, filters_1x1=256,
                                   filters_3x3_reduce=160, filters_3x3=320,
                                   filters_5x5_reduce=32, filters_5x5=128, filters_pool_proj=128)

    maxpool4_3x3_s2 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(inception_4e)

    inception_5a = inception_model(input=maxpool4_3x3_s2, filters_1x1=256,
                                   filters_3x3_reduce=160, filters_3x3=320,
                                   filters_5x5_reduce=32, filters_5x5=128, filters_pool_proj=128)

    inception_5b = inception_model(input=inception_5a, filters_1x1=384,
                                   filters_3x3_reduce=192, filters_3x3=384,
                                   filters_5x5_reduce=48, filters_5x5=128, filters_pool_proj=128)

    averagepool1_7x7_s1 = AveragePooling2D(pool_size=(7, 7), strides=(7, 7), padding='same')(inception_5b)

    drop1 = Dropout(rate=0.4)(averagepool1_7x7_s1)

    linear = Dense(units=4, activation='softmax', kernel_regularizer=l2(0.01))(Flatten()(drop1))
    last = linear


    model = Model(inputs=input, outputs=last)
    return model
    
if __name__ == '__main__':
    model = define_model()
    print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 16, 16, 64)   9472        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 8, 8, 64)     0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 8, 8, 64)     4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 8, 192)    110784      conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 4, 4, 192)    0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 96)     18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 4, 4, 16)     3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 192)    0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 4, 4, 64)     12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 4, 4, 128)    110720      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 4, 4, 32)     12832       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 32)     6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 4, 4, 256)    0           conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 4, 4, 128)    32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 32)     8224        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 256)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 128)    32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 192)    221376      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 96)     76896       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 4, 4, 64)     16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 480)    0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 2, 2, 480)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 2, 2, 96)     46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 2, 2, 16)     7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 2, 2, 480)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 2, 2, 192)    92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 2, 2, 208)    179920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 2, 2, 48)     19248       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 2, 2, 64)     30784       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 2, 2, 512)    0           conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 2, 2, 112)    57456       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 2, 2, 24)     12312       concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 2, 2, 512)    0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 2, 2, 160)    82080       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 2, 2, 224)    226016      conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 2, 2, 64)     38464       conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 2, 2, 64)     32832       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 2, 2, 512)    0           conv2d_21[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 2, 2, 128)    65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 2, 2, 24)     12312       concatenate_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 2, 2, 512)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 2, 2, 128)    65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 2, 2, 256)    295168      conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 2, 2, 64)     38464       conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 2, 2, 64)     32832       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 2, 2, 512)    0           conv2d_27[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 2, 2, 144)    73872       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 2, 2, 32)     16416       concatenate_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 2, 2, 512)    0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 2, 2, 112)    57456       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 2, 2, 288)    373536      conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 2, 2, 64)     51264       conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 2, 2, 64)     32832       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 2, 2, 528)    0           conv2d_33[0][0]
#                                                                  conv2d_35[0][0]
#                                                                  conv2d_37[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 2, 2, 160)    84640       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 2, 2, 32)     16928       concatenate_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 2, 2, 528)    0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 2, 2, 256)    135424      concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 2, 2, 320)    461120      conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 2, 2, 128)    102528      conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 2, 2, 128)    67712       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 2, 2, 832)    0           conv2d_39[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 1, 1, 832)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 1, 1, 160)    133280      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 1, 1, 32)     26656       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 1, 1, 832)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 1, 1, 256)    213248      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 1, 1, 320)    461120      conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 1, 1, 128)    102528      conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 1, 1, 128)    106624      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 1, 1, 832)    0           conv2d_45[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 1, 1, 192)    159936      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 1, 1, 48)     39984       concatenate_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 1, 1, 832)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 1, 1, 384)    319872      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 1, 1, 384)    663936      conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 1, 1, 128)    153728      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 1, 1, 128)    106624      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 1, 1, 1024)   0           conv2d_51[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 1024)   0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1, 1, 1024)   0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4)            4100        flatten[0][0]
# ==================================================================================================
# Total params: 5,977,652
# Trainable params: 5,977,652
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
sgd = tf.keras.optimizers.SGD(lr=1e-6, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd, loss='categorical_crossentropy' , metrics=['accuracy'])

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator()
validation_datagen = ImageDataGenerator()
test_datagen = ImageDataGenerator()

training_set = train_datagen.flow_from_directory('data_all/train/', 
                                                 target_size = (224,224), 
                                                 batch_size = 10, 
                                                 class_mode = 'categorical', 
                                                 shuffle = True)

validation_set = test_datagen.flow_from_directory('data_all/validation/', 
                                            target_size = (224,224), 
                                            batch_size = 1, 
                                            class_mode = 'categorical')

test_set = test_datagen.flow_from_directory('data_all/test/', 
                                            target_size = (224,224), 
                                            batch_size = 1, 
                                            class_mode = 'categorical')
# Out:
# Using TensorFlow backend.
# Found 17723 images belonging to 4 classes.
# Found 2214 images belonging to 4 classes.
# Found 2214 images belonging to 4 classes.

# %%
checkpoint_path = "training_3/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(patience = 3)

# %%
training = model.fit(training_set, 
                     epochs = 30, 
                     validation_data = validation_set, 
                     verbose = 1, 
                     callbacks = [cp_callback, early_stopping])
# Out:
# Epoch 1/30
# 1773/1773 [==============================] - ETA: 0s - loss: 83.5549 - accuracy: 0.2967
# Epoch 00001: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1937s 1s/step - loss: 83.5549 - accuracy: 0.2967 - val_loss: 83.4178 - val_accuracy: 0.4241
# Epoch 2/30
# 1773/1773 [==============================] - ETA: 0s - loss: 83.4065 - accuracy: 0.3640
# Epoch 00002: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1879s 1s/step - loss: 83.4065 - accuracy: 0.3640 - val_loss: 83.2901 - val_accuracy: 0.5023
# Epoch 3/30
# 1773/1773 [==============================] - ETA: 0s - loss: 83.2710 - accuracy: 0.4278
# Epoch 00003: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1865s 1s/step - loss: 83.2710 - accuracy: 0.4278 - val_loss: 83.1530 - val_accuracy: 0.5741
# Epoch 4/30
# 1773/1773 [==============================] - ETA: 0s - loss: 83.1413 - accuracy: 0.4732
# Epoch 00004: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1835s 1s/step - loss: 83.1413 - accuracy: 0.4732 - val_loss: 83.0143 - val_accuracy: 0.6581
# Epoch 5/30
# 1773/1773 [==============================] - ETA: 0s - loss: 83.0126 - accuracy: 0.5127
# Epoch 00005: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1832s 1s/step - loss: 83.0126 - accuracy: 0.5127 - val_loss: 82.8791 - val_accuracy: 0.7525
# Epoch 6/30
# 1773/1773 [==============================] - ETA: 0s - loss: 82.8895 - accuracy: 0.5459
# Epoch 00006: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1827s 1s/step - loss: 82.8895 - accuracy: 0.5459 - val_loss: 82.7458 - val_accuracy: 0.7873
# Epoch 7/30
# 1773/1773 [==============================] - ETA: 0s - loss: 82.7606 - accuracy: 0.5930
# Epoch 00007: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1830s 1s/step - loss: 82.7606 - accuracy: 0.5930 - val_loss: 82.6143 - val_accuracy: 0.8198
# Epoch 8/30
# 1773/1773 [==============================] - ETA: 0s - loss: 82.6377 - accuracy: 0.6374
# Epoch 00008: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1826s 1s/step - loss: 82.6377 - accuracy: 0.6374 - val_loss: 82.4832 - val_accuracy: 0.8491
# Epoch 9/30
# 1773/1773 [==============================] - ETA: 0s - loss: 82.5054 - accuracy: 0.6881
# Epoch 00009: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1826s 1s/step - loss: 82.5054 - accuracy: 0.6881 - val_loss: 82.3533 - val_accuracy: 0.8681
# Epoch 10/30
# 1773/1773 [==============================] - ETA: 0s - loss: 82.3848 - accuracy: 0.7279
# Epoch 00010: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1824s 1s/step - loss: 82.3848 - accuracy: 0.7279 - val_loss: 82.2189 - val_accuracy: 0.8866
# Epoch 11/30
# 1773/1773 [==============================] - ETA: 0s - loss: 82.2506 - accuracy: 0.7723
# Epoch 00011: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1824s 1s/step - loss: 82.2506 - accuracy: 0.7723 - val_loss: 82.0908 - val_accuracy: 0.8934
# Epoch 12/30
# 1773/1773 [==============================] - ETA: 0s - loss: 82.1261 - accuracy: 0.8108
# Epoch 00012: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1823s 1s/step - loss: 82.1261 - accuracy: 0.8108 - val_loss: 81.9663 - val_accuracy: 0.9015
# Epoch 13/30
# 1773/1773 [==============================] - ETA: 0s - loss: 82.0040 - accuracy: 0.8378
# Epoch 00013: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1829s 1s/step - loss: 82.0040 - accuracy: 0.8378 - val_loss: 81.8531 - val_accuracy: 0.9142
# Epoch 14/30
# 1773/1773 [==============================] - ETA: 0s - loss: 81.8932 - accuracy: 0.8580
# Epoch 00014: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1818s 1s/step - loss: 81.8932 - accuracy: 0.8580 - val_loss: 81.7558 - val_accuracy: 0.9246
# Epoch 15/30
# 1773/1773 [==============================] - ETA: 0s - loss: 81.7921 - accuracy: 0.8739
# Epoch 00015: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1821s 1s/step - loss: 81.7921 - accuracy: 0.8739 - val_loss: 81.6671 - val_accuracy: 0.9237
# Epoch 16/30
# 1773/1773 [==============================] - ETA: 0s - loss: 81.6971 - accuracy: 0.8892
# Epoch 00016: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1822s 1s/step - loss: 81.6971 - accuracy: 0.8892 - val_loss: 81.5757 - val_accuracy: 0.9327
# Epoch 17/30
# 1773/1773 [==============================] - ETA: 0s - loss: 81.6039 - accuracy: 0.9027
# Epoch 00017: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1818s 1s/step - loss: 81.6039 - accuracy: 0.9027 - val_loss: 81.4887 - val_accuracy: 0.9408
# Epoch 18/30
# 1773/1773 [==============================] - ETA: 0s - loss: 81.5238 - accuracy: 0.9102
# Epoch 00018: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1825s 1s/step - loss: 81.5238 - accuracy: 0.9102 - val_loss: 81.4116 - val_accuracy: 0.9476
# Epoch 19/30
# 1773/1773 [==============================] - ETA: 0s - loss: 81.4409 - accuracy: 0.9176
# Epoch 00019: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1812s 1s/step - loss: 81.4409 - accuracy: 0.9176 - val_loss: 81.3438 - val_accuracy: 0.9422
# Epoch 20/30
# 1773/1773 [==============================] - ETA: 0s - loss: 81.3683 - accuracy: 0.9237
# Epoch 00020: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1814s 1s/step - loss: 81.3683 - accuracy: 0.9237 - val_loss: 81.2687 - val_accuracy: 0.9494
# Epoch 21/30
# 1773/1773 [==============================] - ETA: 0s - loss: 81.2978 - accuracy: 0.9274
# Epoch 00021: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1819s 1s/step - loss: 81.2978 - accuracy: 0.9274 - val_loss: 81.2016 - val_accuracy: 0.9530
# Epoch 22/30
# 1773/1773 [==============================] - ETA: 0s - loss: 81.2257 - accuracy: 0.9313
# Epoch 00022: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1821s 1s/step - loss: 81.2257 - accuracy: 0.9313 - val_loss: 81.1362 - val_accuracy: 0.9521
# Epoch 23/30
# 1773/1773 [==============================] - ETA: 0s - loss: 81.1516 - accuracy: 0.9396
# Epoch 00023: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1813s 1s/step - loss: 81.1516 - accuracy: 0.9396 - val_loss: 81.0733 - val_accuracy: 0.9548
# Epoch 24/30
# 1773/1773 [==============================] - ETA: 0s - loss: 81.0908 - accuracy: 0.9399
# Epoch 00024: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1812s 1s/step - loss: 81.0908 - accuracy: 0.9399 - val_loss: 81.0106 - val_accuracy: 0.9575
# Epoch 25/30
# 1773/1773 [==============================] - ETA: 0s - loss: 81.0236 - accuracy: 0.9421
# Epoch 00025: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1806s 1s/step - loss: 81.0236 - accuracy: 0.9421 - val_loss: 80.9458 - val_accuracy: 0.9603
# Epoch 26/30
# 1773/1773 [==============================] - ETA: 0s - loss: 80.9615 - accuracy: 0.9444
# Epoch 00026: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1807s 1s/step - loss: 80.9615 - accuracy: 0.9444 - val_loss: 80.8864 - val_accuracy: 0.9593
# Epoch 27/30
# 1773/1773 [==============================] - ETA: 0s - loss: 80.8988 - accuracy: 0.9476
# Epoch 00027: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1815s 1s/step - loss: 80.8988 - accuracy: 0.9476 - val_loss: 80.8244 - val_accuracy: 0.9598
# Epoch 28/30
# 1773/1773 [==============================] - ETA: 0s - loss: 80.8354 - accuracy: 0.9497
# Epoch 00028: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1808s 1s/step - loss: 80.8354 - accuracy: 0.9497 - val_loss: 80.7642 - val_accuracy: 0.9621
# Epoch 29/30
# 1773/1773 [==============================] - ETA: 0s - loss: 80.7753 - accuracy: 0.9502
# Epoch 00029: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1818s 1s/step - loss: 80.7753 - accuracy: 0.9502 - val_loss: 80.7083 - val_accuracy: 0.9634
# Epoch 30/30
# 1773/1773 [==============================] - ETA: 0s - loss: 80.7133 - accuracy: 0.9531
# Epoch 00030: saving model to training_3/cp.ckpt
# 1773/1773 [==============================] - 1813s 1s/step - loss: 80.7133 - accuracy: 0.9531 - val_loss: 80.6510 - val_accuracy: 0.9634

# %%
results = model.evaluate(test_set)
# Out:
# 2214/2214 [==============================] - 199s 90ms/step - loss: 80.6639 - accuracy: 0.9648

# %%
model.save('saved_model/GoogLeNet')
# Out:
# WARNING:tensorflow:From /home/user/anaconda3/envs/tf/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: saved_model/GoogLeNet/assets

# %%
model.save('GoogLeNet.h5')

# %%
converter = tf.lite.TFLiteConverter.from_saved_model('saved_model/GoogLeNet')
tflite_model = converter.convert()
open("converted_model_googlenet.tflite", "wb").write(tflite_model)
# Out:
# 23956580
